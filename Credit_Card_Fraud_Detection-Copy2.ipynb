# %% [markdown]
# # Credit Card Fraud Classification with a simple Wide and Deep Neural Network architecture, using TensorFlow, Keras and Talos.
#
#
# <br>
# <div style="text-align: justify">
# This piece of work illustrates how to build a simple wide & deep neural network and make classification on credit card fraud dataset from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud). The dataset contains transactions over a two-days period in September 2013.<br>
#
# The Wide & Deep neural network architecture, introduced by [Heng-Tze Cheng et al](https://dl.acm.org/doi/pdf/10.1145/2988450.2988454), connects all or part of the inputs directly to the output layer; hence makes it possible for the neural network to learn both deep patterns (using the deep path) and simple rules (through the short path).<br>
#
# Just like performing a Grid-/Random-Search with Scikit-Learn, a set of hyperparameters will be optimized using Talos.
# </div>

# %%
#we will try to build a reproductible experience, although without 
#guarantee, due to the extremely random nature of Neural Networks
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

from sklearn.utils import class_weight
from sklearn.metrics import make_scorer

from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier

# Importing the Keras libraries and packages from TensorFlow
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.activations import relu, sigmoid
from tensorflow.keras.losses import binary_crossentropy, logcosh
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.models import model_from_json
import tensorflow as tf

import talos
from talos import scan, Evaluate, Reporting 
from talos.utils import early_stopper, lr_normalizer
from talos.utils.gpu_utils import parallel_gpu_jobs
from talos.utils.recover_best_model import recover_best_model

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

data = pd.read_csv("/home/moukouba/data_science/python/datasets/creditcard.csv")
# Out:
# Using TensorFlow backend.

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
#We drop the Time column. It could be important, but we'll avoid the underlying preprocessing headache
df = data.drop('Time', axis=1)

# %%
#Separate the attributes (X) with the target variable (y)
X, y = df.iloc[:,:-1], data['Class']

# %%
#Check for the class balance by plotting the frequency histogram
count_classes = pd.value_counts(y, sort = True)
labels = ["Normal","Fraud"]

count_classes.plot(kind = 'bar', rot=0, figsize=(6, 5))
plt.xticks(range(2), labels)
plt.title("Frequency by observation number")
plt.xlabel("Class")
plt.ylabel("Number of Observations");

# %%
dict(count_classes)
# Out:
# {0: 284315, 1: 492}

# %% [markdown]
# We have a case of highly imbalanced classes. As it will be shown later, the case will be dealt with using a penalized classifier (a.k.a Cost Sensitive Classifier).

# %%
#Checking for missing values
X.isnull().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %%
# create a histogram plot for each attribute
ax = X.hist(bins=50, figsize=(16, 14))
# disable axis labels to avoid the clutter
for axis in ax.flatten():
    axis.set_xticklabels([])
    axis.set_yticklabels([])
# show the plot
plt.show()

# %% [markdown]
# <div style="text-align: justify">
# The above histograms show that, some features are near-normally distributed, some are skewed and so on. Since these are PCA-derived features and we do not have further information on the original data, we will avoid diving into, somehow, time consuming and cumbersome feature engineering and complicated data preprocessing, keeping in mind that, the problem at hand being an anomaly detection problem, any inconsistency in the data, such as outliers, might be of a valuable importance and could necessitate keeping them for better performance of the model.
# </div>

# %% [markdown]
# <div style="text-align: justify">
# For the sake of simplicity but also, as it will be seen, without impinging that much on the performance of the model, only features whose importance is greater than or equal to the median (based on importance weights) will be kept. We ended up with 15 best features, as shown below.
#
# This can be implemented straightforwardly using the "feature_selection" module from scikit-learn. We will be using ExtraTreesClassifier as estimator.
# </div>

# %%
selector = SelectFromModel(estimator=ExtraTreesClassifier(n_estimators=500, n_jobs=-1),
                           threshold='median').fit(X, y)
indices = selector.get_support(indices=True)
X_selected = X.iloc[:, indices]
X_selected
# Out:
#                V2        V3        V4        V7        V9       V10       V11  \
# 0       -0.072781  2.536347  1.378155  0.239599  0.363787  0.090794 -0.551600
# 1        0.266151  0.166480  0.448154 -0.078803 -0.255425 -0.166974  1.612727
# 2       -1.340163  1.773209  0.379780  0.791461 -1.514654  0.207643  0.624501
# 3       -0.185226  1.792993 -0.863291  0.237609 -1.387024 -0.054952 -0.226487
# 4        0.877737  1.548718  0.403034  0.592941  0.817739  0.753074 -0.822843
# ...           ...       ...       ...       ...       ...       ...       ...
# 284802  10.071785 -9.834783 -2.066656 -4.918215  1.914428  4.356170 -1.593105
# 284803  -0.055080  2.035030 -0.738589  0.024330  0.584800 -0.975926 -0.150189
# 284804  -0.301254 -3.249640 -0.557828 -0.296827  0.432454 -0.484782  0.411614
# 284805   0.530483  0.702510  0.689799 -0.686180  0.392087 -0.399126 -1.933849
# 284806  -0.189733  0.703337 -0.506271  1.577006  0.486180 -0.915427 -1.040458
#
#              V12       V14       V16       V17       V18       V19       V21  \
# 0      -0.617801 -0.311169 -0.470401  0.207971  0.025791  0.403993 -0.018307
# 1       1.065235 -0.143772  0.463917 -0.114805 -0.183361 -0.145783 -0.225775
# 2       0.066084 -0.165946 -2.890083  1.109969 -0.121359 -2.261857  0.247998
# 3       0.178228 -0.287924 -1.059647 -0.684093  1.965775 -1.232622 -0.108300
# 4       0.538196 -1.119670 -0.451449 -0.237033 -0.038195  0.803487 -0.009431
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  2.711941  4.626942  1.107641  1.991691  0.510632 -0.682920  0.213454
# 284803  0.915802 -0.675143 -0.711757 -0.025693 -1.221179 -1.545556  0.214205
# 284804  0.063119 -0.510602  0.140716  0.313502  0.395652 -0.577252  0.232045
# 284805 -0.962886  0.449624 -0.608577  0.509928  1.113981  2.897849  0.265245
# 284806 -0.031513 -0.084316 -0.302620 -0.660377  0.167430 -0.256117  0.261057
#
#              V26
# 0      -0.189115
# 1       0.125895
# 2      -0.139097
# 3      -0.221929
# 4       0.502292
# ...          ...
# 284802  0.250034
# 284803 -0.395255
# 284804 -0.087371
# 284805  0.546668
# 284806 -0.818267
#
# [284807 rows x 15 columns]

# %% [markdown]
# <div style="text-align: justify">
# Now, we can split the data into train and test sets, and Min-Max scale it to $0 - 1$ range, using train_test_split and MinMaxScaler, respectively.
# </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size = 0.3, random_state=42, stratify=y)

# %%
b_scaled = X_train.copy()
b_scaled_test = X_test.copy()

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train = scaler.fit_transform(b_scaled)
scaled_test = scaler.transform(b_scaled_test)

x_train = scaled_train
x_test = scaled_test

x_train.shape
# Out:
# (199364, 15)

# %%
# deriving the class weights for cost sensitive classification
class_weights = np.around(class_weight.compute_class_weight('balanced', np.unique(y), y), 1)
class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# {0: 0.5, 1: 289.4}

# %%
# Setting the dictionary of the hyperparameter to be included in the optimisation process 
p = {'neurons1': [8, 16, 32, 64, 128],
     'neurons2': [8, 16, 32, 64, 128],
     'batch_size': [16, 32, 64, 128, 512, 1024, 2048, 4096],
     'epochs': (10, 50, 5),
     'dropout1': (0.1, 0.6, 5),
     'dropout2': (0.1, 0.6, 5),
     'optimizer': ['Adam', 'RMSprop', 'SGD'],
     'losses': [logcosh, binary_crossentropy],
     'activation1':[relu, sigmoid],
     'activation2':[relu, sigmoid]}

# %% [markdown]
# <div style="text-align: justify">
# Now, we build a basic wide & deep neural network, with two dropout-regularized hidden layers and one concatenate layer. It is worth noting that two metrics, viz. the Area Under the ROC curve (ROC_AUC) and the Area Unde Precision-Recall Curve (PR_AUC) will be used. This makes the process very costly computationally though, it was important as to check for the best metric between the two.
# </div>

# %%
def model_builder(x_train, y_train, x_val, y_val, params):
    
    tf.keras.backend.clear_session()

    input_layer = tf.keras.layers.Input(shape=(15,))

    hidden_layer1 = Dense(params['neurons1'], kernel_initializer='uniform', 
                          activation=params['activation1'], use_bias=True)(input_layer)
    drop_out1 = Dropout(params['dropout1'])(hidden_layer1)
        
    hidden_layer2 = Dense(params['neurons2'], kernel_initializer='uniform', 
                          activation=params['activation2'], use_bias=True)(drop_out1)
    drop_out2 = Dropout(params['dropout2'])(hidden_layer2)

    concatenated = tf.keras.layers.Concatenate()([input_layer, drop_out2])
   
    output = Dense(1, activation='sigmoid')(concatenated)
            
    model = Model(inputs=[input_layer], outputs=[output])

    model.compile(optimizer=params['optimizer'], loss=params['losses'], 
                  metrics=[tf.keras.metrics.AUC(curve='PR', name='PR_AUC')])

    history = model.fit(x_train, y_train, batch_size=params['batch_size'],
                    epochs=params['epochs'], verbose=0, validation_data=[x_val, y_val],
                    callbacks=[early_stopper(epochs=params['epochs'], mode='moderate', monitor='val_loss')])

    return history, model

# %% [markdown]
# <div style="text-align: justify">
# The next step is to run the experiments creating a Scan object - which we called "scrutinizer" - and split the GPU memory in two for two parallel jobs. Note that, the Scan object may hold many more parameters, like saving the weights of every single model in a folder created by experiment_name='folder_name' (here 'fraud_classification'). <br><br>
# Moreover, the "fraction_limit" parameter sets the fraction of grid random sampling. Here, we can see that only 0.5% of all the possible combinations was used - that is, 3000 rounds - and the process took 93:41:09 to execute, on a modest GTX-1050 GPU.
# </div>

# %%
parallel_gpu_jobs(0.5)

scrutinizer = talos.Scan(x=x_train, y=y_train, x_val=x_test, y_val=y_test, seed=42, 
                         model=model_builder, experiment_name='fraud_classification', 
                         params=p, fraction_limit=0.05, reduction_metric='val_loss')
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]
#
#
#
#   0%|          | 1/30000 [00:31<263:05:55, 31.57s/it]
#
#
#
#   0%|          | 2/30000 [00:40<206:39:29, 24.80s/it]
#
#
#
#   0%|          | 3/30000 [00:49<168:07:56, 20.18s/it]
#
#
#
#   0%|          | 4/30000 [01:34<229:39:24, 27.56s/it]
#
#
#
#   0%|          | 5/30000 [02:18<270:23:03, 32.45s/it]
#
#
#
#   0%|          | 6/30000 [02:27<212:15:00, 25.48s/it]
#
#
#
#   0%|          | 7/30000 [03:09<253:41:27, 30.45s/it]
#
#
#
#   0%|          | 8/30000 [03:51<282:06:55, 33.86s/it]
#
#
#
#   0%|          | 9/30000 [05:05<381:07:54, 45.75s/it]
#
#
#
#   0%|          | 10/30000 [08:17<747:21:31, 89.71s/it]
#
#
#
#   0%|          | 11/30000 [08:44<589:44:56, 70.80s/it]
#
#
#
#   0%|          | 12/30000 [09:22<508:07:23, 61.00s/it]
#
#
#
#   0%|          | 13/30000 [09:58<446:44:33, 53.63s/it]
#
#
#
#   0%|          | 14/30000 [12:45<730:17:43, 87.68s/it]
#
#
#
#   0%|          | 15/30000 [13:16<588:32:51, 70.66s/it]
#
#
#
#   0%|          | 16/30000 [17:11<998:28:48, 119.88s/it]
#
#
#
#   0%|          | 17/30000 [17:35<759:37:30, 91.21s/it]
#
#
#
#   0%|          | 18/30000 [18:00<592:18:06, 71.12s/it]
#
#
#
#   0%|          | 19/30000 [18:21<468:41:40, 56.28s/it]
#
#
#
#   0%|          | 20/30000 [20:30<649:04:01, 77.94s/it]
#
#
#
#   0%|          | 21/30000 [21:06<544:40:24, 65.41s/it]
#
#
#
#   0%|          | 22/30000 [21:42<472:19:11, 56.72s/it]
#
#
#
#   0%|          | 23/30000 [23:15<561:07:10, 67.39s/it]
#
#
#
#   0%|          | 24/30000 [23:56<497:17:45, 59.72s/it]
#
#
#
#   0%|          | 25/30000 [26:15<694:03:50, 83.36s/it]
#
#
#
#   0%|          | 26/30000 [26:25<512:04:38, 61.50s/it]
#
#
#
#   0%|          | 27/30000 [27:26<508:33:20, 61.08s/it]
#
#
#
#   0%|          | 28/30000 [27:35<379:55:08, 45.63s/it]
#
#
#
#   0%|          | 29/30000 [27:40<276:59:22, 33.27s/it]
#
#
#
#   0%|          | 30/30000 [29:01<398:28:23, 47.86s/it]
#
#
#
#   0%|          | 31/30000 [29:29<346:59:32, 41.68s/it]
#
#
#
#   0%|          | 32/30000 [38:48<1640:30:40, 197.07s/it]
#
#
#
#   0%|          | 33/30000 [39:01<1180:04:24, 141.76s/it]
#
#
#
#   0%|          | 34/30000 [44:09<1594:26:50, 191.55s/it]
#
#
#
#   0%|          | 35/30000 [44:33<1176:31:18, 141.35s/it]
#
#
#
#   0%|          | 36/30000 [45:04<899:44:19, 108.10s/it]
#
#
#
#   0%|          | 37/30000 [45:30<696:56:07, 83.74s/it]
#
#
#
#   0%|          | 38/30000 [46:47<680:09:53, 81.72s/it]
#
#
#
#   0%|          | 39/30000 [49:57<949:29:51, 114.09s/it]
#
#
#
#   0%|          | 40/30000 [50:22<727:53:04, 87.46s/it]
#
#
#
#   0%|          | 41/30000 [53:06<918:19:11, 110.35s/it]
#
#
#
#   0%|          | 42/30000 [53:47<743:40:26, 89.37s/it]
#
#
#
#   0%|          | 43/30000 [53:58<549:33:54, 66.04s/it]
#
#
#
#   0%|          | 44/30000 [54:26<455:04:45, 54.69s/it]
#
#
#
#   0%|          | 45/30000 [56:09<574:28:40, 69.04s/it]
#
#
#
#   0%|          | 46/30000 [1:01:43<1235:56:35, 148.54s/it]
#
#
#
#   0%|          | 47/30000 [1:02:15<946:20:22, 113.74s/it]
#
#
#
#   0%|          | 48/30000 [1:02:24<684:27:45, 82.27s/it]
#
#
#
#   0%|          | 49/30000 [1:02:55<554:58:23, 66.71s/it]
#
#
#
#   0%|          | 50/30000 [1:03:57<544:19:03, 65.43s/it]
#
#
#
#   0%|          | 51/30000 [1:04:05<400:25:25, 48.13s/it]
#
#
#
#   0%|          | 52/30000 [1:04:28<336:41:47, 40.47s/it]
#
#
#
#   0%|          | 53/30000 [1:04:37<258:57:05, 31.13s/it]
#
#
#
#   0%|          | 54/30000 [1:05:24<299:59:44, 36.06s/it]
#
#
#
#   0%|          | 55/30000 [1:06:10<324:51:48, 39.06s/it]
#
#
#
#   0%|          | 56/30000 [1:06:16<241:22:50, 29.02s/it]
#
#
#
#   0%|          | 57/30000 [1:06:41<230:10:16, 27.67s/it]
#
#
#
#   0%|          | 58/30000 [1:08:51<485:43:16, 58.40s/it]
#
#
#
#   0%|          | 59/30000 [1:09:56<503:54:52, 60.59s/it]
#
#
#
#   0%|          | 60/30000 [1:10:12<391:15:08, 47.04s/it]
#
#
#
#   0%|          | 61/30000 [1:10:20<294:19:46, 35.39s/it]
#
#
#
#   0%|          | 62/30000 [1:10:23<213:49:44, 25.71s/it]
#
#
#
#   0%|          | 63/30000 [1:10:34<177:10:03, 21.30s/it]
#
#
#
#   0%|          | 64/30000 [1:11:58<333:48:15, 40.14s/it]
#
#
#
#   0%|          | 65/30000 [1:12:29<310:19:29, 37.32s/it]
#
#
#
#   0%|          | 66/30000 [1:12:37<236:49:04, 28.48s/it]
#
#
#
#   0%|          | 67/30000 [1:12:58<218:59:49, 26.34s/it]
#
#
#
#   0%|          | 68/30000 [1:15:10<482:35:31, 58.04s/it]
#
#
#
#   0%|          | 69/30000 [1:18:18<805:11:38, 96.85s/it]
#
#
#
#   0%|          | 70/30000 [1:19:00<668:16:03, 80.38s/it]
#
#
#
#   0%|          | 71/30000 [1:20:33<699:50:27, 84.18s/it]
#
#
#
#   0%|          | 72/30000 [1:20:48<528:35:32, 63.58s/it]
#
#
#
#   0%|          | 73/30000 [1:21:13<432:50:48, 52.07s/it]
#
#
#
#   0%|          | 74/30000 [1:21:48<388:37:28, 46.75s/it]
#
#
#
#   0%|          | 75/30000 [1:23:54<587:11:32, 70.64s/it]
#
#
#
#   0%|          | 76/30000 [1:23:58<419:54:48, 50.52s/it]
#
#
#
#   0%|          | 77/30000 [1:24:17<341:06:06, 41.04s/it]
#
#
#
#   0%|          | 78/30000 [1:25:09<370:24:54, 44.57s/it]
#
#
#
#   0%|          | 79/30000 [1:25:18<279:42:40, 33.65s/it]
#
#
#
#   0%|          | 80/30000 [1:25:21<203:37:40, 24.50s/it]
#
#
#
#   0%|          | 81/30000 [1:28:20<590:22:34, 71.04s/it]
#
#
#
#   0%|          | 82/30000 [1:28:33<445:59:14, 53.67s/it]
#
#
#
#   0%|          | 83/30000 [1:29:03<384:46:47, 46.30s/it]
#
#
#
#   0%|          | 84/30000 [1:29:16<302:05:13, 36.35s/it]
#
#
#
#   0%|          | 85/30000 [1:29:42<276:29:45, 33.27s/it]
#
#
#
#   0%|          | 86/30000 [1:31:38<484:07:54, 58.26s/it]
#
#
#
#   0%|          | 87/30000 [1:33:27<609:32:42, 73.36s/it]
#
#
#
#   0%|          | 88/30000 [1:33:40<460:26:45, 55.42s/it]
#
#
#
#   0%|          | 89/30000 [1:34:11<397:34:26, 47.85s/it]
#
#
#
#   0%|          | 90/30000 [1:36:57<693:39:41, 83.49s/it]
#
#
#
#   0%|          | 91/30000 [1:37:49<613:23:20, 73.83s/it]
#
#
#
#   0%|          | 92/30000 [1:42:53<1188:53:07, 143.11s/it]
#
#
#
#   0%|          | 93/30000 [1:43:23<906:35:40, 109.13s/it]
#
#
#
#   0%|          | 94/30000 [1:48:37<1415:44:14, 170.42s/it]
#
#
#
#   0%|          | 95/30000 [1:48:51<1026:37:12, 123.59s/it]
#
#
#
#   0%|          | 96/30000 [1:49:32<820:20:21, 98.76s/it]
#
#
#
#   0%|          | 97/30000 [1:50:04<654:21:36, 78.78s/it]
#
#
#
#   0%|          | 98/30000 [1:50:16<486:52:15, 58.62s/it]
#
#
#
#   0%|          | 99/30000 [1:51:47<569:51:37, 68.61s/it]
#
#
#
#   0%|          | 100/30000 [1:52:17<473:02:04, 56.95s/it]
#
#
#
#   0%|          | 101/30000 [1:52:41<389:37:33, 46.91s/it]
#
#
#
#   0%|          | 102/30000 [1:52:46<286:11:27, 34.46s/it]
#
#
#
#   0%|          | 103/30000 [1:53:02<239:42:56, 28.87s/it]
#
#
#
#   0%|          | 104/30000 [1:53:08<184:00:37, 22.16s/it]
#
#
#
#   0%|          | 105/30000 [1:53:26<172:58:23, 20.83s/it]
#
#
#
#   0%|          | 106/30000 [1:53:57<198:34:12, 23.91s/it]
#
#
#
#   0%|          | 107/30000 [1:54:23<202:57:07, 24.44s/it]
#
#
#
#   0%|          | 108/30000 [1:55:04<244:36:32, 29.46s/it]
#
#
#
#   0%|          | 109/30000 [1:55:11<187:38:00, 22.60s/it]
#
#
#
#   0%|          | 110/30000 [1:56:39<352:19:32, 42.43s/it]
#
#
#
#   0%|          | 111/30000 [1:57:05<310:00:21, 37.34s/it]
#
#
#
#   0%|          | 112/30000 [1:57:29<277:31:55, 33.43s/it]
#
#
#
#   0%|          | 113/30000 [1:57:55<258:24:05, 31.13s/it]
#   0%|          | 114/30000 [1:58:38<289:03:37, 34.82s/it]
#
#
#
#   0%|          | 115/30000 [1:59:51<383:03:45, 46.14s/it]
#
#
#
#   0%|          | 116/30000 [2:00:22<345:06:35, 41.57s/it]
#
#
#
#   0%|          | 117/30000 [2:00:28<257:25:12, 31.01s/it]
#
#
#
#   0%|          | 118/30000 [2:01:03<266:02:04, 32.05s/it]
#
#
#
#   0%|          | 119/30000 [2:02:19<375:34:46, 45.25s/it]
#
#
#
#   0%|          | 120/30000 [2:04:29<587:10:31, 70.74s/it]
#
#
#
#   0%|          | 121/30000 [2:04:58<483:49:17, 58.29s/it]
#
#
#
#   0%|          | 122/30000 [2:05:27<410:05:52, 49.41s/it]
#
#
#
#   0%|          | 123/30000 [2:07:31<595:44:06, 71.78s/it]
#
#
#
#   0%|          | 124/30000 [2:09:07<656:28:19, 79.10s/it]
#
#
#
#   0%|          | 125/30000 [2:18:29<1858:49:18, 223.99s/it]
#
#
#
#   0%|          | 126/30000 [2:18:49<1351:14:31, 162.83s/it]
#
#
#
#   0%|          | 127/30000 [2:19:01<973:57:41, 117.37s/it]
#
#
#
#   0%|          | 128/30000 [2:19:12<711:26:23, 85.74s/it]
#
#
#
#   0%|          | 129/30000 [2:19:16<507:05:05, 61.11s/it]
#
#
#
#   0%|          | 130/30000 [2:19:57<456:39:52, 55.04s/it]
#
#
#
#   0%|          | 131/30000 [2:20:16<366:24:18, 44.16s/it]
#
#
#
#   0%|          | 132/30000 [2:21:12<397:10:15, 47.87s/it]
#
#
#
#   0%|          | 133/30000 [2:22:07<415:21:28, 50.06s/it]
#
#
#
#   0%|          | 134/30000 [2:23:49<543:51:54, 65.56s/it]
#
#
#
#   0%|          | 135/30000 [2:24:11<435:19:14, 52.47s/it]
#
#
#
#   0%|          | 136/30000 [2:31:38<1416:49:50, 170.79s/it]
#
#
#
#   0%|          | 137/30000 [2:32:06<1061:59:35, 128.02s/it]
#
#
#
#   0%|          | 138/30000 [2:32:49<848:40:20, 102.31s/it]
#
#
#
#   0%|          | 139/30000 [2:33:17<665:19:06, 80.21s/it]
#
#
#
#   0%|          | 140/30000 [2:33:29<495:18:13, 59.72s/it]
#
#
#
#   0%|          | 141/30000 [2:33:54<408:31:45, 49.26s/it]
#
#
#
#   0%|          | 142/30000 [2:35:11<478:14:30, 57.66s/it]
#
#
#
#   0%|          | 143/30000 [2:35:31<383:37:00, 46.25s/it]
#
#
#
#   0%|          | 144/30000 [2:35:55<327:36:25, 39.50s/it]
#
#
#
#   0%|          | 145/30000 [2:36:07<259:26:47, 31.28s/it]
#
#
#
#   0%|          | 146/30000 [2:39:51<739:28:54, 89.17s/it]
#
#
#
#   0%|          | 147/30000 [2:40:36<629:03:37, 75.86s/it]
#
#
#
#   0%|          | 148/30000 [2:40:55<487:53:12, 58.84s/it]
#
#
#
#   0%|          | 149/30000 [2:41:19<401:22:45, 48.41s/it]
#
#
#
#   0%|          | 150/30000 [2:41:24<292:44:04, 35.30s/it]
#
#
#
#   1%|          | 151/30000 [2:41:53<278:04:52, 33.54s/it]
#
#
#
#   1%|          | 152/30000 [2:42:18<257:46:12, 31.09s/it]
#
#
#
#   1%|          | 153/30000 [2:42:50<259:07:02, 31.25s/it]
#
#
#
#   1%|          | 154/30000 [2:43:56<346:11:02, 41.76s/it]
#
#
#
#   1%|          | 155/30000 [2:44:17<294:32:49, 35.53s/it]
#
#
#
#   1%|          | 156/30000 [2:44:54<297:50:50, 35.93s/it]
#
#
#
#   1%|          | 157/30000 [2:48:55<808:05:17, 97.48s/it]
#
#
#
#   1%|          | 158/30000 [2:49:21<628:58:42, 75.88s/it]
#
#
#
#   1%|          | 159/30000 [2:49:49<511:23:12, 61.69s/it]
#
#
#
#   1%|          | 160/30000 [2:52:58<826:45:45, 99.74s/it]
#
#
#
#   1%|          | 161/30000 [3:02:12<1955:53:40, 235.97s/it]
#
#
#
#   1%|          | 162/30000 [3:02:49<1461:31:13, 176.33s/it]
#
#
#
#   1%|          | 163/30000 [3:03:44<1159:57:37, 139.96s/it]
#
#
#
#   1%|          | 164/30000 [3:04:02<856:33:53, 103.35s/it]
#
#
#
#   1%|          | 165/30000 [3:06:15<929:47:38, 112.19s/it]
#
#
#
#   1%|          | 166/30000 [3:06:20<663:52:35, 80.11s/it]
#
#
#
#   1%|          | 167/30000 [3:06:42<520:18:46, 62.79s/it]
#
#
#
#   1%|          | 168/30000 [3:06:45<371:51:43, 44.87s/it]
#
#
#
#   1%|          | 169/30000 [3:06:53<277:53:14, 33.54s/it]
#
#
#
#   1%|          | 170/30000 [3:07:07<229:23:36, 27.68s/it]
#
#
#
#   1%|          | 171/30000 [3:07:55<280:28:38, 33.85s/it]
#
#
#
#   1%|          | 172/30000 [3:08:42<313:52:33, 37.88s/it]
#
#
#
#   1%|          | 173/30000 [3:10:00<413:18:31, 49.88s/it]
#
#
#
#   1%|          | 174/30000 [3:10:27<356:13:40, 43.00s/it]
#
#
#
#   1%|          | 175/30000 [3:19:38<1618:47:35, 195.39s/it]
#
#
#
#   1%|          | 176/30000 [3:19:53<1171:26:10, 141.40s/it]
#
#
#
#   1%|          | 177/30000 [3:20:21<888:59:01, 107.31s/it]
#
#
#
#   1%|          | 178/30000 [3:20:31<646:57:14, 78.10s/it]
#
#
#
#   1%|          | 179/30000 [3:26:09<1293:51:41, 156.20s/it]
#
#
#
#   1%|          | 180/30000 [3:26:39<980:18:48, 118.35s/it]
#
#
#
#   1%|          | 181/30000 [3:26:44<697:10:04, 84.17s/it]
#
#
#
#   1%|          | 182/30000 [3:27:00<528:34:44, 63.82s/it]
#
#
#
#   1%|          | 183/30000 [3:27:03<377:03:53, 45.53s/it]
#
#
#
#   1%|          | 184/30000 [3:27:43<363:11:37, 43.85s/it]
#
#
#
#   1%|          | 185/30000 [3:29:46<560:14:24, 67.65s/it]
#
#
#
#   1%|          | 186/30000 [3:29:53<408:14:52, 49.30s/it]
#
#
#
#   1%|          | 187/30000 [3:29:59<302:34:08, 36.54s/it]
#
#
#
#   1%|          | 188/30000 [3:30:10<237:52:08, 28.72s/it]
#
#
#
#   1%|          | 189/30000 [3:30:35<227:53:40, 27.52s/it]
#
#
#
#   1%|          | 190/30000 [3:31:13<253:51:33, 30.66s/it]
#
#
#
#   1%|          | 191/30000 [3:31:43<252:23:42, 30.48s/it]
#
#
#
#   1%|          | 192/30000 [3:32:05<231:24:48, 27.95s/it]
#
#
#
#   1%|          | 193/30000 [3:32:23<207:07:24, 25.02s/it]
#
#
#
#   1%|          | 194/30000 [3:32:52<217:56:58, 26.32s/it]
#
#
#
#   1%|          | 195/30000 [3:33:26<235:29:41, 28.44s/it]
#
#
#
#   1%|          | 196/30000 [3:34:47<368:02:42, 44.46s/it]
#
#
#
#   1%|          | 197/30000 [3:35:33<371:18:32, 44.85s/it]
#
#
#
#   1%|          | 198/30000 [3:35:57<319:41:30, 38.62s/it]
#
#
#
#   1%|          | 199/30000 [3:36:18<274:13:00, 33.13s/it]
#
#
#
#   1%|          | 200/30000 [3:37:26<362:09:38, 43.75s/it]
#
#
#
#   1%|          | 201/30000 [3:38:57<479:19:57, 57.91s/it]
#
#
#
#   1%|          | 202/30000 [3:39:00<343:56:29, 41.55s/it]
#
#
#
#   1%|          | 203/30000 [3:39:25<302:31:22, 36.55s/it]
#
#
#
#   1%|          | 204/30000 [3:39:46<263:21:00, 31.82s/it]
#
#
#
#   1%|          | 205/30000 [3:39:57<210:22:16, 25.42s/it]
#
#
#
#   1%|          | 206/30000 [3:40:43<261:34:33, 31.61s/it]
#
#
#
#   1%|          | 207/30000 [3:41:37<318:08:09, 38.44s/it]
#
#
#
#   1%|          | 208/30000 [3:41:50<254:49:47, 30.79s/it]
#
#
#
#   1%|          | 209/30000 [3:42:22<257:58:01, 31.17s/it]
#
#
#
#   1%|          | 210/30000 [3:42:52<253:41:57, 30.66s/it]
#
#
#
#   1%|          | 211/30000 [3:43:25<260:48:31, 31.52s/it]
#
#
#
#   1%|          | 212/30000 [3:45:25<480:48:16, 58.11s/it]
#
#
#
#   1%|          | 213/30000 [3:45:52<403:28:30, 48.76s/it]
#
#
#
#   1%|          | 214/30000 [3:46:18<347:46:16, 42.03s/it]
#
#
#
#   1%|          | 215/30000 [3:46:44<306:44:51, 37.08s/it]
#
#
#
#   1%|          | 216/30000 [3:46:50<229:16:12, 27.71s/it]
#
#
#
#   1%|          | 217/30000 [3:47:28<255:43:31, 30.91s/it]
#
#
#
#   1%|          | 218/30000 [3:48:21<309:43:59, 37.44s/it]
#
#
#
#   1%|          | 219/30000 [3:48:52<294:00:03, 35.54s/it]
#
#
#
#   1%|          | 220/30000 [3:49:12<255:03:09, 30.83s/it]
#
#
#
#   1%|          | 221/30000 [3:49:53<280:42:13, 33.93s/it]
#
#
#
#   1%|          | 222/30000 [3:50:17<256:22:04, 30.99s/it]
#
#
#
#   1%|          | 223/30000 [3:50:45<249:22:08, 30.15s/it]
#
#
#
#   1%|          | 224/30000 [3:51:09<234:11:56, 28.32s/it]
#   1%|          | 225/30000 [3:51:17<182:27:39, 22.06s/it]
#
#
#
#   1%|          | 226/30000 [3:52:15<271:50:45, 32.87s/it]
#
#
#
#   1%|          | 227/30000 [3:52:53<285:38:58, 34.54s/it]
#
#
#
#   1%|          | 228/30000 [3:54:25<426:24:56, 51.56s/it]
#
#
#
#   1%|          | 229/30000 [3:54:34<321:53:02, 38.92s/it]
#
#
#
#   1%|          | 230/30000 [3:54:46<255:58:54, 30.96s/it]
#
#
#
#   1%|          | 231/30000 [3:55:04<221:44:37, 26.82s/it]
#
#
#
#   1%|          | 232/30000 [3:55:38<241:43:34, 29.23s/it]
#
#
#
#   1%|          | 233/30000 [3:55:49<195:50:25, 23.68s/it]
#
#
#
#   1%|          | 234/30000 [3:56:37<255:54:42, 30.95s/it]
#
#
#
#   1%|          | 235/30000 [3:57:19<284:04:09, 34.36s/it]
#
#
#
#   1%|          | 236/30000 [3:57:54<283:24:30, 34.28s/it]
#
#
#
#   1%|          | 237/30000 [3:58:34<298:22:50, 36.09s/it]
#
#
#
#   1%|          | 238/30000 [4:02:47<837:21:29, 101.29s/it]
#
#
#
#   1%|          | 239/30000 [4:03:19<665:15:51, 80.47s/it]
#
#
#
#   1%|          | 240/30000 [4:03:34<502:09:19, 60.74s/it]
#
#
#
#   1%|          | 241/30000 [4:05:41<666:46:19, 80.66s/it]
#
#
#
#   1%|          | 242/30000 [4:06:53<644:03:51, 77.92s/it]
#
#
#
#   1%|          | 243/30000 [4:07:13<500:50:19, 60.59s/it]
#
#
#
#   1%|          | 244/30000 [4:07:22<374:52:33, 45.35s/it]
#
#
#
#   1%|          | 245/30000 [4:07:43<312:57:18, 37.86s/it]
#
#
#
#   1%|          | 246/30000 [4:16:39<1547:38:35, 187.25s/it]
#
#
#
#   1%|          | 247/30000 [4:17:04<1147:09:35, 138.80s/it]
#
#
#
#   1%|          | 248/30000 [4:18:22<995:26:26, 120.45s/it]
#
#
#
#   1%|          | 249/30000 [4:18:47<757:58:01, 91.72s/it]
#
#
#
#   1%|          | 250/30000 [4:18:51<542:16:44, 65.62s/it]
#
#
#
#   1%|          | 251/30000 [4:20:01<551:15:00, 66.71s/it]
#
#
#
#   1%|          | 252/30000 [4:20:18<429:05:42, 51.93s/it]
#
#
#
#   1%|          | 253/30000 [4:20:43<361:55:02, 43.80s/it]
#
#
#
#   1%|          | 254/30000 [4:21:13<326:51:48, 39.56s/it]
#
#
#
#   1%|          | 255/30000 [4:22:26<409:24:03, 49.55s/it]
#
#
#
#   1%|          | 256/30000 [4:22:42<327:55:06, 39.69s/it]
#
#
#
#   1%|          | 257/30000 [4:28:24<1077:30:53, 130.42s/it]
#
#
#
#   1%|          | 258/30000 [4:35:46<1848:12:55, 223.71s/it]
#
#
#
#   1%|          | 259/30000 [4:36:10<1353:13:17, 163.80s/it]
#
#
#
#   1%|          | 260/30000 [4:38:07<1237:47:10, 149.83s/it]
#
#
#
#   1%|          | 261/30000 [4:38:10<873:16:23, 105.71s/it]
#
#
#
#   1%|          | 262/30000 [4:38:29<659:41:04, 79.86s/it]
#
#
#
#   1%|          | 263/30000 [4:39:22<592:29:50, 71.73s/it]
#
#
#
#   1%|          | 264/30000 [4:39:39<457:10:52, 55.35s/it]
#
#
#
#   1%|          | 265/30000 [4:40:09<393:02:16, 47.58s/it]
#
#
#
#   1%|          | 266/30000 [4:40:45<365:58:15, 44.31s/it]
#
#
#
#   1%|          | 267/30000 [4:42:11<469:42:25, 56.87s/it]
#
#
#
#   1%|          | 268/30000 [4:43:14<482:51:18, 58.46s/it]
#
#
#
#   1%|          | 269/30000 [4:43:48<421:59:47, 51.10s/it]
#
#
#
#   1%|          | 270/30000 [4:44:26<391:02:56, 47.35s/it]
#
#
#
#   1%|          | 271/30000 [4:44:30<283:11:07, 34.29s/it]
#
#
#
#   1%|          | 272/30000 [4:44:35<210:41:15, 25.51s/it]
#
#
#
#   1%|          | 273/30000 [4:44:56<199:08:36, 24.12s/it]
#
#
#
#   1%|          | 274/30000 [4:45:30<224:43:50, 27.22s/it]
#
#
#
#   1%|          | 275/30000 [4:45:47<197:33:39, 23.93s/it]
#
#
#
#   1%|          | 276/30000 [4:47:38<414:37:29, 50.22s/it]
#
#
#
#   1%|          | 277/30000 [4:48:40<444:34:42, 53.85s/it]
#
#
#
#   1%|          | 278/30000 [4:49:19<406:22:25, 49.22s/it]
#
#
#
#   1%|          | 279/30000 [4:49:41<340:11:16, 41.21s/it]
#
#
#
#   1%|          | 280/30000 [4:51:01<436:03:20, 52.82s/it]
#
#
#
#   1%|          | 281/30000 [4:51:42<407:02:10, 49.31s/it]
#
#
#
#   1%|          | 282/30000 [4:52:30<403:17:14, 48.85s/it]
#
#
#
#   1%|          | 283/30000 [4:52:40<305:40:07, 37.03s/it]
#
#
#
#   1%|          | 284/30000 [4:52:59<261:27:49, 31.68s/it]
#
#
#
#   1%|          | 285/30000 [4:54:05<345:29:06, 41.86s/it]
#
#
#
#   1%|          | 286/30000 [4:55:36<469:33:36, 56.89s/it]
#
#
#
#   1%|          | 287/30000 [4:56:55<522:22:04, 63.29s/it]
#
#
#
#   1%|          | 288/30000 [4:58:41<627:38:07, 76.05s/it]
#
#
#
#   1%|          | 289/30000 [4:59:13<520:58:46, 63.13s/it]
#
#
#
#   1%|          | 290/30000 [4:59:41<433:01:16, 52.47s/it]
#
#
#
#   1%|          | 291/30000 [5:01:43<605:12:00, 73.34s/it]
#
#
#
#   1%|          | 292/30000 [5:02:42<569:58:25, 69.07s/it]
#
#
#
#   1%|          | 293/30000 [5:03:06<457:11:13, 55.40s/it]
#
#
#
#   1%|          | 294/30000 [5:03:45<417:22:29, 50.58s/it]
#
#
#
#   1%|          | 295/30000 [5:04:07<345:22:06, 41.86s/it]
#
#
#
#   1%|          | 296/30000 [5:08:14<855:15:00, 103.65s/it]
#
#
#
#   1%|          | 297/30000 [5:08:36<651:56:28, 79.02s/it]
#
#
#
#   1%|          | 298/30000 [5:08:43<474:30:33, 57.51s/it]
#
#
#
#   1%|          | 299/30000 [5:09:56<511:22:01, 61.98s/it]
#
#
#
#   1%|          | 300/30000 [5:11:08<537:38:15, 65.17s/it]
#
#
#
#   1%|          | 301/30000 [5:11:36<443:51:41, 53.80s/it]
#
#
#
#   1%|          | 302/30000 [5:11:41<323:31:17, 39.22s/it]
#
#
#
#   1%|          | 303/30000 [5:14:04<581:36:48, 70.51s/it]
#
#
#
#   1%|          | 304/30000 [5:14:50<519:55:59, 63.03s/it]
#
#
#
#   1%|          | 305/30000 [5:15:04<400:12:43, 48.52s/it]
#
#
#
#   1%|          | 306/30000 [5:16:41<518:08:51, 62.82s/it]
#
#
#
#   1%|          | 307/30000 [5:16:51<389:13:38, 47.19s/it]
#
#
#
#   1%|          | 308/30000 [5:21:55<1022:31:50, 123.98s/it]
#
#
#
#   1%|          | 309/30000 [5:22:17<772:22:40, 93.65s/it]
#
#
#
#   1%|          | 310/30000 [5:24:14<828:13:28, 100.42s/it]
#
#
#
#   1%|          | 311/30000 [5:24:21<597:57:03, 72.51s/it]
#
#
#
#   1%|          | 312/30000 [5:24:32<445:19:35, 54.00s/it]
#
#
#
#   1%|          | 313/30000 [5:27:00<679:30:03, 82.40s/it]
#
#
#
#   1%|          | 314/30000 [5:27:20<524:04:09, 63.55s/it]
#
#
#
#   1%|          | 315/30000 [5:27:28<386:10:40, 46.83s/it]
#
#
#
#   1%|          | 316/30000 [5:27:35<289:07:11, 35.06s/it]
#
#
#
#   1%|          | 317/30000 [5:27:43<221:53:55, 26.91s/it]
#
#
#
#   1%|          | 318/30000 [5:27:57<189:08:20, 22.94s/it]
#
#
#
#   1%|          | 319/30000 [5:28:41<241:33:45, 29.30s/it]
#
#
#
#   1%|          | 320/30000 [5:29:13<246:32:41, 29.90s/it]
#
#
#
#   1%|          | 321/30000 [5:29:37<232:30:48, 28.20s/it]
#
#
#
#   1%|          | 322/30000 [5:29:45<183:09:05, 22.22s/it]
#
#
#
#   1%|          | 323/30000 [5:30:23<222:38:51, 27.01s/it]
#
#
#
#   1%|          | 324/30000 [5:30:51<225:01:05, 27.30s/it]
#
#
#
#   1%|          | 325/30000 [5:32:18<371:16:12, 45.04s/it]
#
#
#
#   1%|          | 326/30000 [5:32:20<266:41:06, 32.35s/it]
#
#
#
#   1%|          | 327/30000 [5:32:26<200:09:55, 24.28s/it]
#
#
#
#   1%|          | 328/30000 [5:37:26<883:20:02, 107.17s/it]
#
#
#
#   1%|          | 329/30000 [5:43:04<1453:58:08, 176.41s/it]
#
#
#
#   1%|          | 330/30000 [5:43:43<1114:01:43, 135.17s/it]
#
#
#
#   1%|          | 331/30000 [5:44:21<872:59:35, 105.93s/it]
#
#
#
#   1%|          | 332/30000 [5:46:10<880:22:01, 106.83s/it]
#
#
#
#   1%|          | 333/30000 [5:46:20<641:46:18, 77.88s/it]
#
#
#
#   1%|          | 334/30000 [5:46:47<514:58:50, 62.49s/it]
#
#
#
#   1%|          | 335/30000 [5:50:29<909:35:40, 110.38s/it]
#   1%|          | 336/30000 [5:50:40<664:59:53, 80.70s/it]
#
#
#
#   1%|          | 337/30000 [5:50:52<494:34:20, 60.02s/it]
#
#
#
#   1%|          | 338/30000 [5:51:47<480:33:49, 58.32s/it]
#
#
#
#   1%|          | 339/30000 [5:52:08<388:45:12, 47.18s/it]
#
#
#
#   1%|          | 340/30000 [5:52:57<393:27:23, 47.76s/it]
#
#
#
#   1%|          | 341/30000 [5:56:34<811:47:32, 98.54s/it]
#
#
#
#   1%|          | 342/30000 [5:57:23<688:59:26, 83.63s/it]
#
#
#
#   1%|          | 343/30000 [5:57:44<533:47:07, 64.80s/it]
#
#
#
#   1%|          | 344/30000 [5:58:00<415:29:03, 50.44s/it]
#
#
#
#   1%|          | 345/30000 [5:59:17<480:14:21, 58.30s/it]
#
#
#
#   1%|          | 346/30000 [5:59:21<346:00:51, 42.01s/it]
#
#
#
#   1%|          | 347/30000 [5:59:37<280:31:01, 34.06s/it]
#
#
#
#   1%|          | 348/30000 [6:03:55<834:38:28, 101.33s/it]
#
#
#
#   1%|          | 349/30000 [6:09:30<1411:52:29, 171.42s/it]
#
#
#
#   1%|          | 350/30000 [6:09:50<1038:21:53, 126.07s/it]
#
#
#
#   1%|          | 351/30000 [6:10:41<853:26:09, 103.62s/it]
#
#
#
#   1%|          | 352/30000 [6:10:59<641:59:41, 77.95s/it]
#
#
#
#   1%|          | 353/30000 [6:11:34<535:37:01, 65.04s/it]
#
#
#
#
#
#
#
#   1%|          | 355/30000 [6:19:24<1413:31:00, 171.65s/it]
#
#
#
#   1%|          | 356/30000 [6:20:11<1106:33:43, 134.38s/it]
#
#
#
#   1%|          | 357/30000 [6:21:50<1018:53:42, 123.74s/it]
#
#
#
#   1%|          | 358/30000 [6:22:09<758:46:56, 92.15s/it]
#
#
#
#   1%|          | 359/30000 [6:22:51<635:39:14, 77.20s/it]
#
#
#
#   1%|          | 360/30000 [6:27:54<1193:36:29, 144.97s/it]
#
#
#
#   1%|          | 361/30000 [6:27:58<845:13:50, 102.66s/it]
#
#
#
#   1%|          | 362/30000 [6:28:11<623:07:17, 75.69s/it]
#
#
#
#   1%|          | 363/30000 [6:28:20<457:48:47, 55.61s/it]
#
#
#
#   1%|          | 364/30000 [6:28:53<402:49:51, 48.93s/it]
#
#
#
#   1%|          | 365/30000 [6:29:26<364:21:37, 44.26s/it]
#
#
#
#   1%|          | 366/30000 [6:33:47<899:07:30, 109.23s/it]
#
#
#
#   1%|          | 367/30000 [6:34:06<675:29:16, 82.06s/it]
#
#
#
#   1%|          | 368/30000 [6:34:47<574:49:09, 69.83s/it]
#
#
#
#   1%|          | 369/30000 [6:35:24<494:08:22, 60.04s/it]
#
#
#
#   1%|          | 370/30000 [6:35:40<385:30:41, 46.84s/it]
#
#
#
#   1%|          | 371/30000 [6:36:27<385:44:44, 46.87s/it]
#
#
#
#   1%|          | 372/30000 [6:37:08<371:29:16, 45.14s/it]
#
#
#
#   1%|          | 373/30000 [6:37:58<382:18:01, 46.45s/it]
#
#
#
#   1%|          | 374/30000 [6:38:10<298:12:50, 36.24s/it]
#
#
#
#   1%|▏         | 375/30000 [6:39:04<342:17:05, 41.59s/it]
#
#
#
#   1%|▏         | 376/30000 [6:39:20<278:13:32, 33.81s/it]
#
#
#
#   1%|▏         | 377/30000 [6:40:30<368:04:34, 44.73s/it]
#
#
#
#   1%|▏         | 378/30000 [6:40:34<267:10:29, 32.47s/it]
#
#
#
#   1%|▏         | 379/30000 [6:40:56<240:58:46, 29.29s/it]
#
#
#
#   1%|▏         | 380/30000 [6:43:42<578:54:34, 70.36s/it]
#
#
#
#   1%|▏         | 381/30000 [6:45:22<651:56:07, 79.24s/it]
#
#
#
#   1%|▏         | 382/30000 [6:45:47<516:51:40, 62.82s/it]
#
#
#
#   1%|▏         | 383/30000 [6:46:19<442:36:04, 53.80s/it]
#
#
#
#   1%|▏         | 384/30000 [6:47:47<526:57:08, 64.05s/it]
#
#
#
#   1%|▏         | 385/30000 [6:56:09<1606:05:08, 195.24s/it]
#
#
#
#   1%|▏         | 386/30000 [6:59:53<1677:02:20, 203.87s/it]
#
#
#
#   1%|▏         | 387/30000 [7:00:48<1309:34:53, 159.20s/it]
#
#
#
#   1%|▏         | 388/30000 [7:01:16<987:27:37, 120.05s/it]
#
#
#
#   1%|▏         | 389/30000 [7:05:17<1285:09:21, 156.24s/it]
#
#
#
#   1%|▏         | 390/30000 [7:06:04<1015:46:07, 123.50s/it]
#
#
#
#   1%|▏         | 391/30000 [7:06:19<748:08:10, 90.96s/it]
#
#
#
#   1%|▏         | 392/30000 [7:07:11<650:51:57, 79.14s/it]
#
#
#
#   1%|▏         | 393/30000 [7:09:46<839:03:23, 102.02s/it]
#
#
#
#   1%|▏         | 394/30000 [7:09:52<600:32:28, 73.02s/it]
#
#
#
#   1%|▏         | 395/30000 [7:10:18<485:40:20, 59.06s/it]
#
#
#
#   1%|▏         | 396/30000 [7:10:30<368:55:48, 44.86s/it]
#
#
#
#   1%|▏         | 397/30000 [7:10:41<285:12:18, 34.68s/it]
#
#
#
#   1%|▏         | 398/30000 [7:12:42<497:51:41, 60.55s/it]
#
#
#
#   1%|▏         | 399/30000 [7:12:56<383:49:09, 46.68s/it]
#
#
#
#   1%|▏         | 400/30000 [7:13:23<336:30:15, 40.93s/it]
#
#
#
#   1%|▏         | 401/30000 [7:13:48<295:29:00, 35.94s/it]
#
#
#
#   1%|▏         | 402/30000 [7:14:03<244:27:01, 29.73s/it]
#
#
#
#   1%|▏         | 403/30000 [7:14:23<221:35:58, 26.95s/it]
#
#
#
#   1%|▏         | 404/30000 [7:14:51<223:27:33, 27.18s/it]
#
#
#
#   1%|▏         | 405/30000 [7:15:06<193:36:15, 23.55s/it]
#
#
#
#   1%|▏         | 406/30000 [7:17:23<473:22:34, 57.58s/it]
#
#
#
#   1%|▏         | 407/30000 [7:20:15<754:23:20, 91.77s/it]
#
#
#
#   1%|▏         | 408/30000 [7:20:18<537:17:36, 65.36s/it]
#
#
#
#   1%|▏         | 409/30000 [7:20:27<396:37:57, 48.25s/it]
#
#
#
#   1%|▏         | 410/30000 [7:21:03<367:01:02, 44.65s/it]
#
#
#
#   1%|▏         | 411/30000 [7:26:03<997:05:10, 121.31s/it]
#
#
#
#   1%|▏         | 412/30000 [7:29:20<1183:39:07, 144.02s/it]
#
#
#
#   1%|▏         | 413/30000 [7:29:27<846:05:25, 102.95s/it]
#
#
#
#   1%|▏         | 414/30000 [7:29:37<616:24:01, 75.00s/it]
#
#
#
#   1%|▏         | 415/30000 [7:34:00<1080:23:11, 131.46s/it]
#
#
#
#   1%|▏         | 416/30000 [7:34:50<878:02:19, 106.85s/it]

# %%
scrutinizer.details
# Out:
# experiment_name        fraud_classification
# random_method              uniform_mersenne
# reduction_method                       None
# reduction_interval                       50
# reduction_window                         20
# reduction_threshold                     0.2
# reduction_metric                   val_loss
# complete_time                06/18/20/21:12
# x_shape                        (199364, 15)
# y_shape                           (199364,)
# dtype: object

# %%
analyze_object = talos.Analyze(scrutinizer)

# %%
analyze_object.data
# Out:
#                 start              end   duration  round_epochs      loss  \
# 0     06/16/20-222513  06/16/20-222517   4.432257             3  0.319975
# 1     06/16/20-222517  06/16/20-222636  78.779595            10  0.209784
# 2     06/16/20-222636  06/16/20-222643   6.511553             5  0.027263
# 3     06/16/20-222643  06/16/20-222753  70.069889            16  0.687313
# 4     06/16/20-222753  06/16/20-222759   5.770446             4  0.207484
# ...               ...              ...        ...           ...       ...
# 2995  06/18/20-211032  06/18/20-211056  23.903631            17  0.082840
# 2996  06/18/20-211056  06/18/20-211119  23.248734            30  0.039997
# 2997  06/18/20-211120  06/18/20-211146  26.821407             9  0.218776
# 2998  06/18/20-211147  06/18/20-211211  24.333296            23  0.261923
# 2999  06/18/20-211211  06/18/20-211228  16.625119             6  0.244152
#
#         PR_AUC   ROC_AUC  val_loss  val_PR_AUC  val_ROC_AUC  \
# 0     0.618890  0.951426  0.351958    0.666116     0.949967
# 1     0.024528  0.598258  0.000738    0.198770     0.614817
# 2     0.655795  0.963877  0.041742    0.641460     0.950710
# 3     0.585375  0.893098  0.008078    0.585896     0.844480
# 4     0.680923  0.966346  0.317841    0.647213     0.953317
# ...        ...       ...       ...         ...          ...
# 2995  0.711889  0.941120  0.075667    0.677170     0.945121
# 2996  0.576389  0.942895  0.018376    0.639634     0.953808
# 2997  0.632282  0.958900  0.184142    0.668516     0.953490
# 2998  0.583162  0.948714  0.162243    0.656942     0.952283
# 2999  0.511923  0.957521  0.198295    0.642910     0.952696
#
#                                activation1  \
# 0        <function relu at 0x7fdf812db440>
# 1     <function sigmoid at 0x7fdf812db560>
# 2        <function relu at 0x7fdf812db440>
# 3        <function relu at 0x7fdf812db440>
# 4        <function relu at 0x7fdf812db440>
# ...                                    ...
# 2995  <function sigmoid at 0x7fdf812db560>
# 2996     <function relu at 0x7fdf812db440>
# 2997  <function sigmoid at 0x7fdf812db560>
# 2998     <function relu at 0x7fdf812db440>
# 2999     <function relu at 0x7fdf812db440>
#
#                                activation2  batch_size  dropout1  dropout2  \
# 0        <function relu at 0x7fdf812db440>         512       0.1       0.1
# 1        <function relu at 0x7fdf812db440>          32       0.5       0.5
# 2        <function relu at 0x7fdf812db440>        1024       0.2       0.2
# 3     <function sigmoid at 0x7fdf812db560>          64       0.4       0.2
# 4        <function relu at 0x7fdf812db440>        2048       0.3       0.1
# ...                                    ...         ...       ...       ...
# 2995     <function relu at 0x7fdf812db440>         512       0.2       0.4
# 2996  <function sigmoid at 0x7fdf812db560>        4096       0.5       0.1
# 2997  <function sigmoid at 0x7fdf812db560>         128       0.3       0.4
# 2998  <function sigmoid at 0x7fdf812db560>        2048       0.4       0.5
# 2999  <function sigmoid at 0x7fdf812db560>         128       0.4       0.5
#
#       epochs                                            losses  neurons1  \
# 0         10  <function binary_crossentropy at 0x7fdf83cefdd0>        16
# 1         46              <function logcosh at 0x7fdf83cefc20>         8
# 2         28              <function logcosh at 0x7fdf83cefc20>        16
# 3         82  <function binary_crossentropy at 0x7fdf83cefdd0>        16
# 4         10  <function binary_crossentropy at 0x7fdf83cefdd0>       128
# ...      ...                                               ...       ...
# 2995      28              <function logcosh at 0x7fdf83cefc20>         8
# 2996      46              <function logcosh at 0x7fdf83cefc20>         8
# 2997      46  <function binary_crossentropy at 0x7fdf83cefdd0>       128
# 2998      82  <function binary_crossentropy at 0x7fdf83cefdd0>         8
# 2999      10  <function binary_crossentropy at 0x7fdf83cefdd0>        64
#
#       neurons2 optimizer
# 0           16   RMSprop
# 1           16   RMSprop
# 2          128   RMSprop
# 3          128   RMSprop
# 4          128      Adam
# ...        ...       ...
# 2995       128       SGD
# 2996        32      Adam
# 2997        32      Adam
# 2998       128      Adam
# 2999         8      Adam
#
# [3000 rows x 20 columns]

# %%
model_id
# Out:
# 2535

# %%
analyze_object.data[['val_PR_AUC']].max()

# %%
analyze_object.data.iloc[2530:2538]
# Out:
#                 start              end   duration  round_epochs      loss  \
# 2530  06/18/20-141206  06/18/20-141235  29.151778            27  0.043485
# 2531  06/18/20-141236  06/18/20-141317  41.567949             3  0.052842
# 2532  06/18/20-141317  06/18/20-141404  47.056744            64  0.097832
# 2533  06/18/20-141405  06/18/20-141431  26.638915            21  0.031270
# 2534  06/18/20-141432  06/18/20-141448  16.517424            15  0.040396
# 2535  06/18/20-141448  06/18/20-141554  65.781538            14  0.467740
# 2536  06/18/20-141554  06/18/20-141608  13.610839             5  0.408992
# 2537  06/18/20-141608  06/18/20-141619  10.600860             9  0.118828
#
#         PR_AUC   ROC_AUC  val_loss  val_PR_AUC  val_ROC_AUC  \
# 2530  0.616390  0.932847  0.009778    0.647972     0.947545
# 2531  0.696690  0.951789  0.035240    0.663342     0.942218
# 2532  0.398907  0.833106  0.086513    0.616302     0.918385
# 2533  0.644633  0.952914  0.008231    0.659429     0.952283
# 2534  0.553803  0.949060  0.015445    0.656906     0.954916
# 2535  0.614610  0.939192  0.006694    0.690909     0.932296
# 2536  0.659282  0.927835  0.255550    0.670511     0.946443
# 2537  0.002093  0.553024  0.114631    0.153523     0.794806
#
#                                activation1  \
# 2530  <function sigmoid at 0x7fdf812db560>
# 2531     <function relu at 0x7fdf812db440>
# 2532     <function relu at 0x7fdf812db440>
# 2533  <function sigmoid at 0x7fdf812db560>
# 2534     <function relu at 0x7fdf812db440>
# 2535     <function relu at 0x7fdf812db440>
# 2536  <function sigmoid at 0x7fdf812db560>
# 2537  <function sigmoid at 0x7fdf812db560>
#
#                                activation2  batch_size  dropout1  dropout2  \
# 2530     <function relu at 0x7fdf812db440>        1024       0.5       0.4
# 2531     <function relu at 0x7fdf812db440>          16       0.3       0.5
# 2532  <function sigmoid at 0x7fdf812db560>        4096       0.1       0.2
# 2533     <function relu at 0x7fdf812db440>        1024       0.1       0.3
# 2534     <function relu at 0x7fdf812db440>        2048       0.5       0.3
# 2535  <function sigmoid at 0x7fdf812db560>          64       0.1       0.1
# 2536     <function relu at 0x7fdf812db440>         128       0.3       0.5
# 2537  <function sigmoid at 0x7fdf812db560>        2048       0.2       0.1
#
#       epochs                                            losses  neurons1  \
# 2530      46              <function logcosh at 0x7fdf83cefc20>        64
# 2531      10              <function logcosh at 0x7fdf83cefc20>        16
# 2532      64              <function logcosh at 0x7fdf83cefc20>        16
# 2533      64              <function logcosh at 0x7fdf83cefc20>        64
# 2534      46              <function logcosh at 0x7fdf83cefc20>         8
# 2535      82  <function binary_crossentropy at 0x7fdf83cefdd0>       128
# 2536      10  <function binary_crossentropy at 0x7fdf83cefdd0>        16
# 2537      46              <function logcosh at 0x7fdf83cefc20>        64
#
#       neurons2 optimizer
# 2530        16   RMSprop
# 2531         8       SGD
# 2532         8       SGD
# 2533        16      Adam
# 2534       128   RMSprop
# 2535        32   RMSprop
# 2536         8      Adam
# 2537        64       SGD

# %%
# The highest PR_AUC achieved on validation set 
analyze_object.high('val_PR_AUC')
# Out:
# 0.6909090280532837

# %%
# The highest ROC_AUC achieved on validation set 
analyze_object.high('val_ROC_AUC')
# Out:
# 0.9614167809486389

# %%
# The best model based on validation PR_AUC
best = scrutinizer.best_model(metric='val_PR_AUC', asc=False)

# %%
# Predicting the Test set results
y_pred = best.predict(x_test)
y_pred = (y_pred > 0.5)

conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=labels, yticklabels=labels, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.70      0.79      0.74       148
#
#     accuracy                           1.00     85443
#    macro avg       0.85      0.89      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# The best model based on validation ROC_AUC
best1 = scrutinizer.best_model(metric='val_ROC_AUC', asc=False)

# %%
# Predicting the Test set results
y_pred1 = best1.predict(x_test)
y_pred1 = (y_pred1 > 0.5)

conf_matrix = confusion_matrix(y_test, y_pred1)

plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=labels, yticklabels=labels, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.84      0.74      0.79       148
#
#     accuracy                           1.00     85443
#    macro avg       0.92      0.87      0.89     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# Get the best model index with highest 'val_categorical_accuracy' 
model_id = analyze_object.data[['val_ROC_AUC']].idxmax()[0]

# model_id = scan_results.data['val_categorical_accuracy'].astype('float').argmax() - 1

# Clear any previous TensorFlow session.
tf.keras.backend.clear_session()

# Load the model parameters from the scanner.
model = model_from_json(scrutinizer.saved_models[model_id])
model.set_weights(scrutinizer.saved_weights[model_id])
model.summary()
model.save('./best_model.h5')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           1024        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            520         dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 23)           0           input_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            24          concatenate[0][0]
# ==================================================================================================
# Total params: 1,568
# Trainable params: 1,568
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Predicting the Test set results
y_pred2 = model.predict(x_test)
y_pred2 = (y_pred2 > 0.5)

conf_matrix = confusion_matrix(y_test, y_pred2)

plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=labels, yticklabels=labels, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

score = roc_auc_score(y_test, y_pred2)
print('ROC AUC: %.3f' % score)

print(classification_report(y_test, y_pred2))
# Out:
# ROC AUC: 0.868
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.84      0.74      0.79       148
#
#     accuracy                           1.00     85443
#    macro avg       0.92      0.87      0.89     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# <div style="text-align: justify">
# As it can be noticed, Talos does not choose the best performing model necessarily as the one with the highest metric, but the one with the best combination of both loss and metric. Moreover, as could be expected for highly imbalanced classes, PR_AUC should be the preferred metric. The best model based on PR_AUC shows a ROC_AUC of $0.885$ (vs $0.892$ for the ROC_AUC based model), but is less prone to False Positives, keeping a good trade off between False Positives and False Negatives.<br><br>
# Besides, it should be noted that, not only the process has the potential of yielding even better results, since only 0.5% of the parameter space was searched, but also we may improve the score by tweaking, say, the architecture of the network or adding more hyperparameters to be searched, at some expense.<br><br>
# It's unfortunate that there is no specific command to pick the model with the highest metric, to see how it would perform, analyzing and comparing its confusion matrix to that of the best model. Although it is still possible to manually track the model with the highest performance through the "analyze_object" and its weights if saved during the scan process, but this is beyond the scope of this work. Talos offers a lot of interesting and easy-to-use functionalities like the "Reporting()" command which consists of access to several meaningful signals related with the experiment, together with the dataframe with results for each permutation, together with the corresponding hyperparameter  configurations.
# </div>
